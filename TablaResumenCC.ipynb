# %%
# CoefCorrel; Dataframe
# Columnas del dataframe: 'r_TD_Tr', 'p_TD_Tr', 'r_TD_Te', 'p_TD_Te', 'r_Tr_Te', 'p_Tr_Te'

def ordenar_valores_cc (dataframe_coeficientes, cc1_str, p1_str, cc2_str, p2_str, cc3_str, p3_str):#Cruce, ramal, exterior
    ## CC1:
    #Contadores
    CC1_num_valores_mas_de_0_5 =0
    CC1_num_valores_mas_de_0 =0
    CC1_num_valores_mas_de_menos_0_5=0
    CC1_num_valores_mas_de_menos_1=0
    #Valores de c y p de cada intervalo:
    CC1_c_mas_de_0_5 = []
    CC1_p_mas_de_0_5 = []
    CC1_c_mas_de_0 = []
    CC1_p_mas_de_0 = []
    CC1_c_mas_de_menos_0_5 = []
    CC1_p_mas_de_menos_0_5 = []
    CC1_c_mas_de_menos_1 = []
    CC1_p_mas_de_menos_1 = []
    #indice:
    i=0
    while i<len(dataframe_coeficientes[cc1_str]):
        if dataframe_coeficientes[cc1_str][i]>0.5:
            CC1_num_valores_mas_de_0_5 = CC1_num_valores_mas_de_0_5 +1
            CC1_c_mas_de_0_5.append(dataframe_coeficientes[cc1_str][i])
            CC1_p_mas_de_0_5.append(dataframe_coeficientes[p1_str][i])
        elif dataframe_coeficientes[cc1_str][i]>0:
            CC1_num_valores_mas_de_0 = CC1_num_valores_mas_de_0 +1
            CC1_c_mas_de_0.append(dataframe_coeficientes[cc1_str][i])
            CC1_p_mas_de_0.append(dataframe_coeficientes[p1_str][i])
        elif dataframe_coeficientes[cc1_str][i]>-0.5:
            CC1_num_valores_mas_de_menos_0_5 = CC1_num_valores_mas_de_menos_0_5 +1
            CC1_c_mas_de_menos_0_5.append(dataframe_coeficientes[cc1_str][i])
            CC1_p_mas_de_menos_0_5.append(dataframe_coeficientes[p1_str][i])
        elif dataframe_coeficientes[cc1_str][i]>=-1:
            CC1_num_valores_mas_de_menos_1 = CC1_num_valores_mas_de_menos_1 +1
            CC1_c_mas_de_menos_1.append(dataframe_coeficientes[cc1_str][i])
            CC1_p_mas_de_menos_1.append(dataframe_coeficientes[p1_str][i])
        # Por si hay errores:
        elif dataframe_coeficientes[cc1_str][i]>=1:
            print('CC mayor de 1, problemas en el código')
        else:
            print('CC menor que -1, problemas en el código')
        i=i+1
    ## CC2:
    #Contadores
    CC2_num_valores_mas_de_0_5 =0
    CC2_num_valores_mas_de_0 =0
    CC2_num_valores_mas_de_menos_0_5=0
    CC2_num_valores_mas_de_menos_1=0
    #Valores de c y p de cada intervalo:
    CC2_c_mas_de_0_5 = []
    CC2_p_mas_de_0_5 = []
    CC2_c_mas_de_0 = []
    CC2_p_mas_de_0 = []
    CC2_c_mas_de_menos_0_5 = []
    CC2_p_mas_de_menos_0_5 = []
    CC2_c_mas_de_menos_1 = []
    CC2_p_mas_de_menos_1 = []
    #indice:
    i=0
    while i<len(dataframe_coeficientes[cc2_str]):
        if dataframe_coeficientes[cc2_str][i]>0.5:
            CC2_num_valores_mas_de_0_5 = CC2_num_valores_mas_de_0_5 +1
            CC2_c_mas_de_0_5.append(dataframe_coeficientes[cc2_str][i])
            CC2_p_mas_de_0_5.append(dataframe_coeficientes[p2_str][i])
        elif dataframe_coeficientes[cc2_str][i]>0:
            CC2_num_valores_mas_de_0 = CC2_num_valores_mas_de_0 +1
            CC2_c_mas_de_0.append(dataframe_coeficientes[cc2_str][i])
            CC2_p_mas_de_0.append(dataframe_coeficientes[p2_str][i])
        elif dataframe_coeficientes[cc2_str][i]>-0.5:
            CC2_num_valores_mas_de_menos_0_5 = CC2_num_valores_mas_de_menos_0_5 +1
            CC2_c_mas_de_menos_0_5.append(dataframe_coeficientes[cc2_str][i])
            CC2_p_mas_de_menos_0_5.append(dataframe_coeficientes[p2_str][i])
        elif dataframe_coeficientes[cc2_str][i]>=-1:
            CC2_num_valores_mas_de_menos_1 = CC2_num_valores_mas_de_menos_1 +1
            CC2_c_mas_de_menos_1.append(dataframe_coeficientes[cc2_str][i])
            CC2_p_mas_de_menos_1.append(dataframe_coeficientes[p2_str][i])
        # Por si hay errores:
        elif dataframe_coeficientes[cc2_str][i]>=1:
            print('CC mayor de 1, problemas en el código')
        else:
            print('CC menor que -1, problemas en el código')
        i=i+1
    
    ## CC3:
    #Contadores
    CC3_num_valores_mas_de_0_5 =0
    CC3_num_valores_mas_de_0 =0
    CC3_num_valores_mas_de_menos_0_5=0
    CC3_num_valores_mas_de_menos_1=0
    #Valores de c y p de cada intervalo:
    CC3_c_mas_de_0_5 = []
    CC3_p_mas_de_0_5 = []
    CC3_c_mas_de_0 = []
    CC3_p_mas_de_0 = []
    CC3_c_mas_de_menos_0_5 = []
    CC3_p_mas_de_menos_0_5 = []
    CC3_c_mas_de_menos_1 = []
    CC3_p_mas_de_menos_1 = []
    #indice:
    i=0
    while i<len(dataframe_coeficientes[cc3_str]):
        if dataframe_coeficientes[cc3_str][i]>0.5:
            CC3_num_valores_mas_de_0_5 = CC3_num_valores_mas_de_0_5 +1
            CC3_c_mas_de_0_5.append(dataframe_coeficientes[cc3_str][i])
            CC3_p_mas_de_0_5.append(dataframe_coeficientes[p3_str][i])
        elif dataframe_coeficientes[cc3_str][i]>0:
            CC3_num_valores_mas_de_0 = CC3_num_valores_mas_de_0 +1
            CC3_c_mas_de_0.append(dataframe_coeficientes[cc3_str][i])
            CC3_p_mas_de_0.append(dataframe_coeficientes[p3_str][i])
        elif dataframe_coeficientes[cc3_str][i]>-0.5:
            CC3_num_valores_mas_de_menos_0_5 = CC3_num_valores_mas_de_menos_0_5 +1
            CC3_c_mas_de_menos_0_5.append(dataframe_coeficientes[cc3_str][i])
            CC3_p_mas_de_menos_0_5.append(dataframe_coeficientes[p3_str][i])
        elif dataframe_coeficientes[cc3_str][i]>=-1:
            CC3_num_valores_mas_de_menos_1 = CC3_num_valores_mas_de_menos_1 +1
            CC3_c_mas_de_menos_1.append(dataframe_coeficientes[cc3_str][i])
            CC3_p_mas_de_menos_1.append(dataframe_coeficientes[p3_str][i])
        # Por si hay errores:
        elif dataframe_coeficientes[cc3_str][i]>=1:
            print('CC mayor de 1, problemas en el código')
        else:
            print('CC menor que -1, problemas en el código')
        i=i+1
        
    
#     #Tabla final
#     print(len(dataframe_coeficientes['r_TD_Tr']))
#     print('ccvalores', 'r_TD_Tr', 'r_TD_Te', 'r_Tr_Te')
#     print('cc>0.5:',CC1_num_valores_mas_de_0_5, CC2_num_valores_mas_de_0_5, CC3_num_valores_mas_de_0_5)
#     print('cc>0:',CC1_num_valores_mas_de_0, CC2_num_valores_mas_de_0, CC3_num_valores_mas_de_0)
#     print('cc>-0.5:',CC1_num_valores_mas_de_menos_0_5, CC2_num_valores_mas_de_menos_0_5, CC3_num_valores_mas_de_menos_0_5)
#     print('cc>-1:', CC1_num_valores_mas_de_menos_1, CC2_num_valores_mas_de_menos_1, CC3_num_valores_mas_de_menos_1)
#     print('total:', CC1_num_valores_mas_de_0_5+CC1_num_valores_mas_de_0+CC1_num_valores_mas_de_menos_0_5+CC1_num_valores_mas_de_menos_1,
#           CC2_num_valores_mas_de_0_5+CC2_num_valores_mas_de_0+CC2_num_valores_mas_de_menos_0_5+CC2_num_valores_mas_de_menos_1,
#           CC3_num_valores_mas_de_0_5+CC3_num_valores_mas_de_0+CC3_num_valores_mas_de_menos_0_5+CC3_num_valores_mas_de_menos_1)
    #Tabla final mejorada:
    total1= CC1_num_valores_mas_de_0_5+CC1_num_valores_mas_de_0+CC1_num_valores_mas_de_menos_0_5+CC1_num_valores_mas_de_menos_1
    total2= CC2_num_valores_mas_de_0_5+CC2_num_valores_mas_de_0+CC2_num_valores_mas_de_menos_0_5+CC2_num_valores_mas_de_menos_1
    total3= CC3_num_valores_mas_de_0_5+CC3_num_valores_mas_de_0+CC3_num_valores_mas_de_menos_0_5+CC3_num_valores_mas_de_menos_1
    d1=pd.Series([CC1_num_valores_mas_de_0_5, CC1_num_valores_mas_de_0, CC1_num_valores_mas_de_menos_0_5, 
                  CC1_num_valores_mas_de_menos_1, total1], index=['cc>0.5', 'cc>0', 'cc>-0.5', 'cc>-1', 'total'])
    d2=pd.Series([CC2_num_valores_mas_de_0_5, CC2_num_valores_mas_de_0, CC2_num_valores_mas_de_menos_0_5, 
                  CC2_num_valores_mas_de_menos_1, total2], index=['cc>0.5', 'cc>0', 'cc>-0.5', 'cc>-1', 'total'])
    d3=pd.Series([CC3_num_valores_mas_de_0_5, CC3_num_valores_mas_de_0, CC3_num_valores_mas_de_menos_0_5, 
                  CC3_num_valores_mas_de_menos_1, total3], index=['cc>0.5', 'cc>0', 'cc>-0.5', 'cc>-1', 'total'])
    df = pd.concat([d1, d2, d3], axis = 1)  
    df.columns = [cc1_str, cc2_str, cc3_str]
    display(df)
    
# ordenar_valores_cc (CoefCorrel, 'r_TD_Tr', 'p_TD_Tr', 'r_TD_Te', 'p_TD_Te', 'r_Tr_Te', 'p_Tr_Te')
